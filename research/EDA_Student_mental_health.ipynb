# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MentalHealthSurvey.csv')

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %%
# Check the shape of the dataset
df.shape
# Out:
# (87, 21)

# %%
# Check the columns in the dataset
df.columns
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'depression', 'anxiety', 'isolation',
#        'future_insecurity', 'stress_relief_activities'],
#       dtype='object')

# %%
# check the null values
df.isnull().sum()
# Out:
# gender                      0
# age                         0
# university                  0
# degree_level                0
# degree_major                0
# academic_year               0
# cgpa                        0
# residential_status          0
# campus_discrimination       0
# sports_engagement           0
# average_sleep               0
# study_satisfaction          0
# academic_workload           0
# academic_pressure           0
# financial_concerns          0
# social_relationships        0
# depression                  0
# anxiety                     0
# isolation                   0
# future_insecurity           0
# stress_relief_activities    0
# dtype: int64

# %%
# check the duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check the data types
df.dtypes
# Out:
# gender                      object
# age                          int64
# university                  object
# degree_level                object
# degree_major                object
# academic_year               object
# cgpa                        object
# residential_status          object
# campus_discrimination       object
# sports_engagement           object
# average_sleep               object
# study_satisfaction           int64
# academic_workload            int64
# academic_pressure            int64
# financial_concerns           int64
# social_relationships         int64
# depression                   int64
# anxiety                      int64
# isolation                    int64
# future_insecurity            int64
# stress_relief_activities    object
# dtype: object

# %%
# check the information on the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    87 non-null     object
#  1   age                       87 non-null     int64
#  2   university                87 non-null     object
#  3   degree_level              87 non-null     object
#  4   degree_major              87 non-null     object
#  5   academic_year             87 non-null     object
#  6   cgpa                      87 non-null     object
#  7   residential_status        87 non-null     object
#  8   campus_discrimination     87 non-null     object
#  9   sports_engagement         87 non-null     object
#  10  average_sleep             87 non-null     object
#  11  study_satisfaction        87 non-null     int64
#  12  academic_workload         87 non-null     int64
#  13  academic_pressure         87 non-null     int64
# ...

# %%
# check the data statistics
df.describe()
# Out:
#              age  study_satisfaction  academic_workload   academic_pressure  \
# count  87.000000           87.000000           87.000000          87.000000
# mean   19.942529            3.931034            3.885057           3.781609
# std     1.623636            1.043174            0.854880           1.125035
# min    17.000000            1.000000            2.000000           1.000000
# 25%    19.000000            3.000000            3.000000           3.000000
# 50%    20.000000            4.000000            4.000000           4.000000
# 75%    21.000000            5.000000            4.500000           5.000000
# max    26.000000            5.000000            5.000000           5.000000
#
#        financial_concerns  social_relationships  depression    anxiety  \
# count           87.000000             87.000000   87.000000  87.000000
# mean             3.390805              2.781609    3.218391   3.218391
# ...

# %%
# chech it balanced or not based on the o/p columns
df['depression'].value_counts()
# Out:
# depression
# 3    21
# 5    20
# 4    19
# 2    14
# 1    13
# Name: count, dtype: int64

# %%
# checked the Audiance are baised on this data set or not
df['gender'].value_counts()
# Out:
# gender
# Male      63
# Female    24
# Name: count, dtype: int64

# %% [markdown]
# ### As per above we can say that the its a quite possible that most of the males are part of this survey

# %%
# check the No of Audiances based on the university
df['university'].value_counts()
# Out:
# university
# PU         56
# UET        10
# COMSATS     9
# FAST        6
# UMT         2
# NUST        1
# VU          1
# UOL         1
# KUST        1
# Name: count, dtype: int64

# %% [markdown]
# #### Most of the audiances are from the PU university

# %% [markdown]
# # EDA

# %%
# chceck the Uniquies values in the dataset
df.nunique()
# Out:
# gender                       2
# age                          8
# university                   9
# degree_level                 2
# degree_major                 4
# academic_year                4
# cgpa                         6
# residential_status           2
# campus_discrimination        2
# sports_engagement            4
# average_sleep                3
# study_satisfaction           5
# academic_workload            4
# academic_pressure            5
# financial_concerns           5
# social_relationships         5
# depression                   5
# anxiety                      5
# isolation                    5
# future_insecurity            5
# stress_relief_activities    38
# dtype: int64

# %%
# as per our problem statement drop stress_relief_activities
df = df.drop('stress_relief_activities',axis=1)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'depression', 'anxiety', 'isolation',
#        'future_insecurity'],
#       dtype='object')

# %%
# check the Uniquies values in the dataset and get the values
unique_values = {}
for columns in df.columns:
    unique_values[columns] = df[columns].unique()

# %%
unique_values
for column, values in unique_values.items():
    print(f"Column: {column}")
    print(f"Unique Values: {values}\n")
# Out:
# Column: gender
# Unique Values: ['Male' 'Female']
#
# Column: age
# Unique Values: [20 26 22 23 21 19 18 17]
#
# Column: university
# Unique Values: ['PU' 'UET' 'FAST' 'COMSATS' 'NUST' 'VU' 'UMT' 'UOL' 'KUST']
#
# Column: degree_level
# Unique Values: ['Undergraduate' 'Postgraduate']
#
# Column: degree_major
# Unique Values: ['Data Science' 'Computer Science' 'Software Engineering'
#  'Information Technology']
#
# Column: academic_year
# Unique Values: ['2nd year' '3rd year' '1st year' '4th year']
#
# Column: cgpa
# Unique Values: ['3.0-3.5' '2.5-3.0' '3.5-4.0' '1.5-2.0' '2.0-2.5' '0.0-0.0']
#
# Column: residential_status
# Unique Values: ['Off-Campus' 'On-Campus']
#
# Column: campus_discrimination
# Unique Values: ['No' 'Yes']
#
# Column: sports_engagement
# Unique Values: ['No Sports' '1-3 times' '7+ times' '4-6 times']
#
# Column: average_sleep
# Unique Values: ['4-6 hrs' '2-4 hrs' '7-8 hrs']
#
# Column: study_satisfaction
# Unique Values: [5 3 4 1 2]
#
# ...

# %%
### Check the countplot of depression
sns.countplot(x='depression', data=df)
# Out:
# <Axes: xlabel='depression', ylabel='count'>

# %%
# check the distribution of depression with age
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='age',hue='depression',palette='Set1')
plt.show()

# %% [markdown]
# #### As per above we can say that the age group 20,21 and above 26 are more likely to have depression and

# %%
# check the depression percentage
plt.figure(figsize=(8, 6))
plt.pie(df['depression'].value_counts(), labels=df['depression'].unique(), autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### As per above we can say that the most of students/ 70% of the students are not suffering from the depression

# %%
# check the distribution of depression with degree_level
plt.figure(figsize=(8, 6))
sns.countplot(data=df,x='degree_level',hue='depression',palette='Set1')
plt.show()

# %% [markdown]
# ### As per above we can say that the undergraduate students are more likely to suffer from depression

# %%
# check the distribution of depression with major dgree
fig,ax= plt.subplots(1,2,figsize=(10,6))
sns.countplot(data=df, x='degree_major', palette='Set1', ax=ax[0]).tick_params(axis='x', rotation=90)
sns.countplot(data=df,x='degree_major',hue='depression',palette='Set1',ax=ax[1]).tick_params(axis='x', rotation=90)
plt.show()
# Out:
# /var/folders/15/vc_j9b113v12tq235z56lnpr0000gn/T/ipykernel_36276/3028260529.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='degree_major', palette='Set1', ax=ax[0]).tick_params(axis='x', rotation=90)

# %% [markdown]
# #### As per above we can say that the every professionsals are in the depression

# %%
# check that the distribution of depression with gender
fig,ax = plt.subplots(1,2,figsize=(8, 6))
sns.countplot(data=df, x='gender', ax=ax[0])
sns.countplot(data=df,x='gender',hue='depression',palette='Set1',ax=ax[1])
plt.show()

# %% [markdown]
# #### we can say that the womens are more depressed than the men bcoz os the counts of the gender

# %%
# check the distribution of depression with cgpa
fig,ax=plt.subplots(1,2,figsize=(20,5))
sns.countplot(x='cgpa',data=df,ax=ax[0])
sns.scatterplot(x='cgpa',y='depression', hue='gender', data=df, ax=ax[1], palette='Set1')
plt.show()

# %% [markdown]
# #### As per abover we can say that the the students hvae cgpa 1.5-2.0 are more stressed than the others

# %%
# check the distribution of depression with average_sleep
fig,ax = plt.subplots(1,2,figsize=(10,5))
sns.countplot(x='average_sleep', data=df, ax=ax[0])
sns.countplot(x='average_sleep', hue='depression', data=df, ax=ax[1], palette='Set1')
plt.show()

# %% [markdown]
# #### As per above we can say that the students those are take rest between 4-6 hrs have more chances to be suffered in depression

# %%
# check the distribution of depression with campus_discrimination
fig,ax = plt.subplots(1,2,figsize=(10,5))
sns.countplot(x='campus_discrimination', data=df, ax=ax[0])
sns.countplot(x='campus_discrimination', hue='depression', data=df, ax=ax[1], palette='Set1')
plt.show()

# %% [markdown]
# #### As per above we can say that the students are facing the campus_discrimination are more stressed

# %%
sns.scatterplot(x=df['academic_pressure'],y=df['financial_concerns'],hue=df['depression'],style=df['gender'],palette='Set1')
# Out:
# <Axes: xlabel='academic_pressure', ylabel='financial_concerns'>

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, palette='Set1')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['cgpa'],orient='v')
plt.show()

# %% [markdown]
# #### as per above we can say that the outliers are present in the cgpa or not consider as outliers

# %%
# check the distribution of depression with future_insecurity
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.countplot(x='future_insecurity', data=df, ax=ax[0])
sns.countplot(x='future_insecurity', hue='depression', data=df, ax=ax[1],palette='Set1')
plt.show()

# %% [markdown]
# #### As per above we can say that the if the candidate have future_insecurity 5 then they have the high chances to be depression

# %%
df.nunique()
# Out:
# gender                   2
# age                      8
# university               9
# degree_level             2
# degree_major             4
# academic_year            4
# cgpa                     6
# residential_status       2
# campus_discrimination    2
# sports_engagement        4
# average_sleep            3
# study_satisfaction       5
# academic_workload        4
# academic_pressure        5
# financial_concerns       5
# social_relationships     5
# depression               5
# anxiety                  5
# isolation                5
# future_insecurity        5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 87 non-null     object
#  1   age                    87 non-null     int64
#  2   university             87 non-null     object
#  3   degree_level           87 non-null     object
#  4   degree_major           87 non-null     object
#  5   academic_year          87 non-null     object
#  6   cgpa                   87 non-null     object
#  7   residential_status     87 non-null     object
#  8   campus_discrimination  87 non-null     object
#  9   sports_engagement      87 non-null     object
#  10  average_sleep          87 non-null     object
#  11  study_satisfaction     87 non-null     int64
#  12  academic_workload      87 non-null     int64
#  13  academic_pressure      87 non-null     int64
# ...

# %% [markdown]
# # Feature Engeneering

# %%
cat_cols=[]
num_cols=[]
for col in df.columns:
    if df[col].dtype=='object':
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
cat_cols,num_cols
# Out:
# (['gender',
#   'university',
#   'degree_level',
#   'degree_major',
#   'academic_year',
#   'cgpa',
#   'residential_status',
#   'campus_discrimination',
#   'sports_engagement',
#   'average_sleep'],
#  ['age',
#   'study_satisfaction',
#   'academic_workload ',
#   'academic_pressure',
#   'financial_concerns',
#   'social_relationships',
#   'depression',
#   'anxiety',
#   'isolation',
#   'future_insecurity'])

# %%
df.head(10)
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
# 5  Female   20        UET  Undergraduate  Computer Science      3rd year
# 6    Male   26         PU   Postgraduate      Data Science      1st year
# 7    Male   22         PU  Undergraduate      Data Science      2nd year
# 8    Male   20    COMSATS  Undergraduate  Computer Science      3rd year
# 9    Male   23    COMSATS  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  \
# 0  3.0-3.5         Off-Campus                    No         No Sports
# ...

# %%
# Assign the values for male or female manually
replace_dict= {0:'Female',1:'Male'}
df['gender']=df['gender'].apply(replace_dict.get)

# %%
df.head(2)
# Out:
#   gender  age university   degree_level      degree_major academic_year  \
# 0   None   20         PU  Undergraduate      Data Science      2nd year
# 1   None   20        UET   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  \
# 0  3.0-3.5         Off-Campus                    No         No Sports
# 1  3.0-3.5         Off-Campus                    No         1-3 times
#
#   average_sleep  study_satisfaction  academic_workload   academic_pressure  \
# 0       4-6 hrs                   5                   4                  5
# 1       4-6 hrs                   5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity
# 0                  2
# 1                  4

# %%
df.columns
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'depression', 'anxiety', 'isolation',
#        'future_insecurity'],
#       dtype='object')

# %%
df['university'].value_counts()
# Out:
# university
# PU         56
# UET        10
# COMSATS     9
# FAST        6
# UMT         2
# NUST        1
# VU          1
# UOL         1
# KUST        1
# Name: count, dtype: int64

# %%
cat_cols
# Out:
# ['gender',
#  'university',
#  'degree_level',
#  'degree_major',
#  'academic_year',
#  'cgpa',
#  'residential_status',
#  'campus_discrimination',
#  'sports_engagement',
#  'average_sleep']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in cat_cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head(2)
# Out:
#    gender  age  university  degree_level  degree_major  academic_year  cgpa  \
# 0       0   20           4             1             1              1     4
# 1       0   20           5             0             0              2     4
#
#    residential_status  campus_discrimination  sports_engagement  \
# 0                   0                      0                  3
# 1                   0                      0                  0
#
#    average_sleep  study_satisfaction  academic_workload   academic_pressure  \
# 0              1                   5                   4                  5
# 1              1                   5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity
# 0                  2
# 1                  4

# %% [markdown]
# # Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('depression',axis=1)
y= df['depression']

# %%
x.shape,y.shape
# Out:
# ((87, 19), (87,))

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((69, 19), (18, 19), (69,), (18,))

# %%
# check the corr
plt.figure(figsize=(20, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'target' is your target column name
target_column = 'depression'  # Replace with your target column

# Calculate the correlation matrix
corr_matrix = df.corr()

# Extract the correlation of all features with the target column
target_corr = corr_matrix[target_column]

# Get the feature with the highest absolute correlation with the target column
most_correlated_feature = target_corr.drop(target_column).abs().idxmax()
highest_correlation_value = target_corr[most_correlated_feature]

print(f"The feature most highly correlated with '{target_column}' is '{most_correlated_feature}' with a correlation of {highest_correlation_value}.")
# Out:
# The feature most highly correlated with 'depression' is 'anxiety' with a correlation of 0.844140894389802.

# %%
top_5_correlated_features = target_corr.drop(target_column).abs().nlargest(5)

print("Top 5 features most highly correlated with the target column:")
print(top_5_correlated_features)
# Out:
# Top 5 features most highly correlated with the target column:
# anxiety               0.844141
# isolation             0.710185
# future_insecurity     0.465185
# financial_concerns    0.379851
# academic_workload     0.379765
# Name: depression, dtype: float64

# %% [markdown]
# # check the feature slection

# %%
# !pip install statsmodels

# %%
pip install pingouin
# Out:
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# ...
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
# Apply feature selection
selector = SelectKBest(score_func=f_classif, k='all')
selector.fit(X_scaled, y)
scores = selector.scores_

# Create a DataFrame with feature scores
feature_scores = pd.DataFrame({'Feature': x.columns, 'Score': scores})
print(feature_scores)
# Out:
#                   Feature      Score
# 0                  gender        NaN
# 1                     age   1.644490
# 2              university   1.219256
# 3            degree_level   0.556493
# 4            degree_major   0.493195
# 5           academic_year   2.339769
# 6                    cgpa   1.778370
# 7      residential_status   0.459390
# 8   campus_discrimination   3.388858
# 9       sports_engagement   2.665200
# 10          average_sleep   1.640236
# 11     study_satisfaction   1.667063
# 12     academic_workload    5.221765
# 13      academic_pressure   4.590716
# 14     financial_concerns   4.267009
# 15   social_relationships   2.735329
# 16                anxiety  54.573477
# 17              isolation  21.074684
# 18      future_insecurity   6.052121
# /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [0] are constant.
# ...

# %%
# X = sm.add_constant(X)

# # Step 3: Calculate VIF for each feature
# vif_data = pd.DataFrame()
# vif_data["feature"] = X.columns
# vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# # Step 4: Display VIF values
# print(vif_data)

# %% [markdown]
# # Build the Model And Training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
import xgboost as xgb

# %% [markdown]
# #### Hyperparameter tunning of the All the models

# %%
models = {
    "lr":LogisticRegression(),
    "rdf":RandomForestClassifier(),
    "xgb":xgb.XGBClassifier()
}

# %%
param_grid = {
    "lr": {
        "penalty": ["l1", "l2"],
        "C": [0.001, 0.01, 0.1, 1, 10, 100],
        "solver": ["liblinear", "saga"],
    },
    "rdf": {
        "n_estimators": [50, 100, 200],
        "max_depth": [3, 5, 7],
        "min_samples_split": [2, 5, 10],
    },
    "xgb": {
        "n_estimators": [50, 100, 200],
        "max_depth": [3, 5, 7]
}
}

# %%
# for name, model in models.items():
#     grid = GridSearchCV(model, param_grid[name], cv=5)
#     grid.fit(X_train, y_train)
#     print(f"Best parameters for {name}: {grid.best_params_}")
#     print(f"Best score for {name}: {grid.best_score_}")

# %% [markdown]
# ##### will do it manually, coz not getting the good score

# %%
lr_grid = {
        "penalty": ["l1", "l2"],
        "C": [0.001, 0.01, 0.1, 1, 10, 100],
        "solver": ["liblinear", "saga"]}

# %%
lr = LogisticRegression()
lr_grd_test = GridSearchCV(lr, lr_grid, cv=5)

# %%
lr_model = lr_grd_test.fit(X_train, y_train)
print(lr_model.score(X_test, y_test))
print(lr_model.best_score_)
print(lr_model.best_params_)
print(lr_model.best_estimator_)
# Out:
# /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
rdf = RandomForestClassifier()

# %%
rdf_param_grid = {
    "n_estimators": [50, 100, 200, 300,400,500,700,100],
    # "max_depth": [3, 5, 7],
    # "min_samples_split": [2, 5, 10],
    "criterion": ['gini', 'entropy', 'log_loss']
}

# %%
rdf_train = GridSearchCV(rdf, rdf_param_grid, cv=5)
rdf_grd_model = rdf_train.fit(X_train, y_train)
print("Best parameters: ", rdf_grd_model.best_params_)
print("best score: ", rdf_grd_model.best_score_)
print("best estimator: ", rdf_grd_model.best_estimator_)
# Out:
# Best parameters:  {'criterion': 'gini', 'n_estimators': 300}
# best score:  0.6384615384615385
# best estimator:  RandomForestClassifier(n_estimators=300)

# %%
xgb_param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.1, 0.3],
    "subsample": [0.5, 0.8, 1],
    "colsample_bytree": [0.5, 0.8, 1]
}

# %%
xgb_grd_model = GridSearchCV(xgb.XGBClassifier(), xgb_param_grid, cv=5)

# %%
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)

# %%
xgb_grd_model.fit(X_train, y_train_encoded)
print("Best Parameters:", xgb_grd_model.best_params_)
print("Best Score:", xgb_grd_model.best_score_)
print("Best Estimator:", xgb_grd_model.best_estimator_)
