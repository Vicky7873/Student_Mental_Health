# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/MentalHealthSurvey.csv')

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %%
df['cgpa'].unique
# Out:
# <bound method Series.unique of 0     3.0-3.5
# 1     3.0-3.5
# 2     2.5-3.0
# 3     2.5-3.0
# 4     3.0-3.5
#        ...
# 82    3.0-3.5
# 83    3.5-4.0
# 84    2.0-2.5
# 85    2.5-3.0
# 86    3.5-4.0
# Name: cgpa, Length: 87, dtype: object>

# %%
cat_cols=[]
num_cols=[]
for col in df.columns:
    if df[col].dtype=='object':
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
df.head(2)
# Out:
#   gender  age university   degree_level      degree_major academic_year  \
# 0   Male   20         PU  Undergraduate      Data Science      2nd year
# 1   Male   20        UET   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder,OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder()
ohe = OneHotEncoder()
oe = OrdinalEncoder()

# %%
cat_cols.remove('gender')

# %%
cat_cols
# Out:
# ['university',
#  'degree_level',
#  'degree_major',
#  'academic_year',
#  'cgpa',
#  'residential_status',
#  'campus_discrimination',
#  'sports_engagement',
#  'average_sleep',
#  'stress_relief_activities']

# %%
# from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# from scipy.sparse import issparse

# # Create OHE and LE instances
# ohe = OneHotEncoder()
# le = LabelEncoder()

# # Iterate over categorical columns
# for col in df[cat_cols]:
#     # Check if column is in the list of columns to be OHE
#     if col in ['university', 'degree_major', 'residential_status']:
#         # Fit and transform the column using OHE
#         encoded_col = ohe.fit_transform(df[[col]])
#         if issparse(encoded_col):
#             # Convert to dense array if it's sparse
#             encoded_col = encoded_col.toarray()
#         df[col] = encoded_col
#     # Check if column is "campus_discrimination"
#     elif col == "campus_discrimination":
#         # Fit and transform the column using LE
#         df[col] = le.fit_transform(df[[col]])
#     # For other categorical columns
#     else:
#         # Fit and transform the column using OHE (or LE if appropriate)
#         encoded_col = oe.fit_transform(df[[col]])
#         if issparse(encoded_col):
#             # Convert to dense array if it's sparse
#             encoded_col = encoded_col.toarray()
#         df[col] = encoded_col

# %%
df.head(2)
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0       1   20         PU  Undergraduate      Data Science      2nd year
# 1       1   20        UET   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df1 = pd.read_csv('/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/MentalHealthSurvey.csv')

# %%
df1[cat_cols].nunique()-df[cat_cols].nunique()
# Out:
# university                  0
# degree_level                0
# degree_major                0
# academic_year               0
# cgpa                        0
# residential_status          0
# campus_discrimination       0
# sports_engagement           0
# average_sleep               0
# stress_relief_activities    0
# dtype: int64

# %%
df1[cat_cols].nunique(),df[cat_cols].nunique()
# Out:
# (university                   9
#  degree_level                 2
#  degree_major                 4
#  academic_year                4
#  cgpa                         6
#  residential_status           2
#  campus_discrimination        2
#  sports_engagement            4
#  average_sleep                3
#  stress_relief_activities    38
#  dtype: int64,
#  university                   9
#  degree_level                 2
#  degree_major                 4
#  academic_year                4
#  cgpa                         6
#  residential_status           2
#  campus_discrimination        2
#  sports_engagement            4
#  average_sleep                3
#  stress_relief_activities    38
#  dtype: int64)

# %%
df1.head(2)
# Out:
#   gender  age university   degree_level      degree_major academic_year  \
# 0   Male   20         PU  Undergraduate      Data Science      2nd year
# 1   Male   20        UET   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df1['university']=le.fit_transform(df1['university'])

# %%
df1.head(2)
# Out:
#   gender  age  university   degree_level      degree_major academic_year  \
# 0   Male   20           4  Undergraduate      Data Science      2nd year
# 1   Male   20           5   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df1['university'].nunique()
# Out:
# 9

# %%
df1['university'].value_counts()
# Out:
# university
# 4    56
# 5    10
# 0     9
# 1     6
# 6     2
# 3     1
# 8     1
# 7     1
# 2     1
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'depression', 'anxiety', 'isolation',
#        'future_insecurity', 'stress_relief_activities'],
#       dtype='object')

# %%
df1.nunique()
# Out:
# gender                       2
# age                          8
# university                   9
# degree_level                 2
# degree_major                 4
# academic_year                4
# cgpa                         6
# residential_status           2
# campus_discrimination        2
# sports_engagement            4
# average_sleep                3
# study_satisfaction           5
# academic_workload            4
# academic_pressure            5
# financial_concerns           5
# social_relationships         5
# depression                   5
# anxiety                      5
# isolation                    5
# future_insecurity            5
# stress_relief_activities    38
# dtype: int64

# %%
cd = ['degree_level','degree_major','academic_year']

for col in cd:
    df1[col]=le.fit_transform(df1[col])

# %%
df1.head(2)
# Out:
#   gender  age  university  degree_level  degree_major  academic_year     cgpa  \
# 0   Male   20           4             1             1              1  3.0-3.5
# 1   Male   20           5             0             0              2  3.0-3.5
#
#   residential_status campus_discrimination sports_engagement  ...  \
# 0         Off-Campus                    No         No Sports  ...
# 1         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df1.nunique()
# Out:
# gender                       2
# age                          8
# university                   9
# degree_level                 2
# degree_major                 4
# academic_year                4
# cgpa                         6
# residential_status           2
# campus_discrimination        2
# sports_engagement            4
# average_sleep                3
# study_satisfaction           5
# academic_workload            4
# academic_pressure            5
# financial_concerns           5
# social_relationships         5
# depression                   5
# anxiety                      5
# isolation                    5
# future_insecurity            5
# stress_relief_activities    38
# dtype: int64

# %%
cat_cols.remove('stress_relief_activities')

# %%
cat_cols
# Out:
# ['university',
#  'degree_level',
#  'degree_major',
#  'academic_year',
#  'cgpa',
#  'residential_status',
#  'campus_discrimination',
#  'sports_engagement',
#  'average_sleep']

# %%
df.head(2)
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0       1   20         PU  Undergraduate      Data Science      2nd year
# 1       1   20        UET   Postgraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    63
# 0    24
# Name: count, dtype: int64

# %%
for col in cat_cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head(2)
# Out:
#    gender  age  university  degree_level  degree_major  academic_year  cgpa  \
# 0       1   20           4             1             1              1     4
# 1       1   20           5             0             0              2     4
#
#    residential_status  campus_discrimination  sports_engagement  ...  \
# 0                   0                      0                  3  ...
# 1                   0                      0                  0  ...
#
#    study_satisfaction  academic_workload   academic_pressure  \
# 0                   5                   4                  5
# 1                   5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
df.nunique()
# Out:
# gender                       2
# age                          8
# university                   9
# degree_level                 2
# degree_major                 4
# academic_year                4
# cgpa                         6
# residential_status           2
# campus_discrimination        2
# sports_engagement            4
# average_sleep                3
# study_satisfaction           5
# academic_workload            4
# academic_pressure            5
# financial_concerns           5
# social_relationships         5
# depression                   5
# anxiety                      5
# isolation                    5
# future_insecurity            5
# stress_relief_activities    38
# dtype: int64

# %%
df1.head(2)
# Out:
#   gender  age  university  degree_level  degree_major  academic_year     cgpa  \
# 0   Male   20           4             1             1              1  3.0-3.5
# 1   Male   20           5             0             0              2  3.0-3.5
#
#   residential_status campus_discrimination sports_engagement  ...  \
# 0         Off-Campus                    No         No Sports  ...
# 1         Off-Campus                    No         1-3 times  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# 0                  5                   4                  5
# 1                  5                   4                  4
#
#    financial_concerns  social_relationships  depression  anxiety  isolation  \
# 0                   4                     3           2        1          1
# 1                   1                     3           3        3          3
#
#    future_insecurity                           stress_relief_activities
# ...

# %%
X_train = pd.read_csv('/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/data_preprocessing/X_train_processed.csv')

# %%
X_train.head(2)
# Out:
#    gender  age  university  degree_level  degree_major  academic_year  cgpa  \
# 0       1   21           4             1             1              1     3
# 1       0   19           5             1             0              2     4
#
#    residential_status  campus_discrimination  sports_engagement  \
# 0                   1                      1                  1
# 1                   1                      0                  3
#
#    average_sleep  study_satisfaction  academic_workload   academic_pressure  \
# 0              1                   3                   4                  5
# 1              1                   3                   5                  5
#
#    financial_concerns  social_relationships  anxiety  isolation  \
# 0                   3                     4        1          1
# 1                   3                     3        5          3
#
#    future_insecurity
# 0                  1
# 1                  5

# %%
X_train.nunique()-df1.nunique()
# Out:
# academic_pressure           0.0
# academic_workload           0.0
# academic_year               0.0
# age                         0.0
# anxiety                     0.0
# average_sleep               0.0
# campus_discrimination       0.0
# cgpa                        0.0
# degree_level                0.0
# degree_major                0.0
# depression                  NaN
# financial_concerns          0.0
# future_insecurity           0.0
# gender                      0.0
# isolation                   0.0
# residential_status          0.0
# social_relationships        0.0
# sports_engagement           0.0
# stress_relief_activities    NaN
# study_satisfaction          0.0
# university                  0.0
# dtype: float64

# %%
import pandas as pd

# %%
X_train = pd.read_csv('/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/data_preprocessing/X_train_processed.csv')
cols = X_train.columns

# %%
cols
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'anxiety', 'isolation', 'future_insecurity'],
#       dtype='object')

# %%
X_train.dtypes
# Out:
# gender                   int64
# age                      int64
# university               int64
# degree_level             int64
# degree_major             int64
# academic_year            int64
# cgpa                     int64
# residential_status       int64
# campus_discrimination    int64
# sports_engagement        int64
# average_sleep            int64
# study_satisfaction       int64
# academic_workload        int64
# academic_pressure        int64
# financial_concerns       int64
# social_relationships     int64
# anxiety                  int64
# isolation                int64
# future_insecurity        int64
# dtype: object

# %%
data = pd.read_csv("/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/MentalHealthSurvey.csv")

# %%
data.nunique()
# Out:
# gender                       2
# age                          8
# university                   9
# degree_level                 2
# degree_major                 4
# academic_year                4
# cgpa                         6
# residential_status           2
# campus_discrimination        2
# sports_engagement            4
# average_sleep                3
# study_satisfaction           5
# academic_workload            4
# academic_pressure            5
# financial_concerns           5
# social_relationships         5
# depression                   5
# anxiety                      5
# isolation                    5
# future_insecurity            5
# stress_relief_activities    38
# dtype: int64

# %%
cat_cols=[]
for col in data.columns:
    if data[col].dtype=='object':
        cat_cols.append(col)

# %%
cat_cols
# Out:
# ['gender',
#  'university',
#  'degree_level',
#  'degree_major',
#  'academic_year',
#  'cgpa',
#  'residential_status',
#  'campus_discrimination',
#  'sports_engagement',
#  'average_sleep',
#  'stress_relief_activities']

# %%
# print the unique values present in columns
for catcol in data[cat_cols]:
    print(f"Unique values in {catcol}: {data[catcol].unique()}")
# Out:
# Unique values in gender: ['Male' 'Female']
# Unique values in university: ['PU' 'UET' 'FAST' 'COMSATS' 'NUST' 'VU' 'UMT' 'UOL' 'KUST']
# Unique values in degree_level: ['Undergraduate' 'Postgraduate']
# Unique values in degree_major: ['Data Science' 'Computer Science' 'Software Engineering'
#  'Information Technology']
# Unique values in academic_year: ['2nd year' '3rd year' '1st year' '4th year']
# Unique values in cgpa: ['3.0-3.5' '2.5-3.0' '3.5-4.0' '1.5-2.0' '2.0-2.5' '0.0-0.0']
# Unique values in residential_status: ['Off-Campus' 'On-Campus']
# Unique values in campus_discrimination: ['No' 'Yes']
# Unique values in sports_engagement: ['No Sports' '1-3 times' '7+ times' '4-6 times']
# Unique values in average_sleep: ['4-6 hrs' '2-4 hrs' '7-8 hrs']
# Unique values in stress_relief_activities: ['Religious Activities, Social Connections, Online Entertainment'
#  'Online Entertainment'
#  'Religious Activities, Sports and Fitness, Online Entertainment'
# ...

# %%
pdd = pd.read_csv('/Users/bhikipallai/Desktop/Projects/Student_Mental_Health/Student_Mental_Health/data/data_preprocessing/X_train_processed.csv')

# %%
pdd.columns
# Out:
# Index(['gender', 'age', 'university', 'degree_level', 'degree_major',
#        'academic_year', 'cgpa', 'residential_status', 'campus_discrimination',
#        'sports_engagement', 'average_sleep', 'study_satisfaction',
#        'academic_workload ', 'academic_pressure', 'financial_concerns',
#        'social_relationships', 'anxiety', 'isolation', 'future_insecurity'],
#       dtype='object')

# %%
pdd['academic_workload'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Applications/anaconda3/envs/studentMH/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'academic_workload'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ...
